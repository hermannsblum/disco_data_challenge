# %%
import import_data
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
businesses = import_data.import_businesses()
# Out:
# Successfully imported businesses with columns ['attributes' 'business_id' 'categories' 'city' 'full_address' 'hours'
#  'latitude' 'longitude' 'name' 'neighborhoods' 'open' 'review_count'
#  'stars' 'state' 'type']

# %%
best = businesses.groupby('city')['name'].count().order(ascending=False)

# %%
best[0:10]
# Out:
# city
# Las Vegas     13601
# Phoenix        8410
# Charlotte      4224
# Scottsdale     4039
# Edinburgh      3031
# Pittsburgh     2724
# Mesa           2347
# Tempe          2258
# Henderson      2130
# Montréal       1870
# Name: name, dtype: int64

# %%
plt.figure(); best[0:20].plot(kind='bar'); plt.axhline(0, color='k')
