# %%
import pandas as pd
import numpy as np
from mpl_toolkits.basemap import Basemap
import json
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-39-86be9ffaf5cf> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from mpl_toolkits.basemap import Basemap
#       4 import json
#
# ImportError: No module named 'mpl_toolkits'

# %%
BASEPATH = 'C:\Code\DataChallenge\src\yelp_dataset_challenge_academic_dataset'
BUSIPATH = '%s\yelp_academic_dataset_business.json' % BASEPATH
REVPATH = '%s\yelp_academic_dataset_review.json' % BASEPATH
USERPATH = '%s\yelp_academic_dataset_user.json' % BASEPATH

# %%
businesses = []
with open(BUSIPATH) as file:
    for line in file:
        businesses.append(json.loads(line))

reviews = []
with open(REVPATH) as file:
    for line in file:
        reviews.append(json.loads(line))
        
users = []
with open(USERPATH) as file:
    for line in file:
        users.append(json.loads(line))

# %%
data = pd.DataFrame(businesses)

# %%
data.columns
# Out:
# Index(['attributes', 'business_id', 'categories', 'city', 'full_address', 'hours', 'latitude', 'longitude', 'name', 'neighborhoods', 'open', 'review_count', 'stars', 'state', 'type'], dtype='object')

# %%
data.describe()
# Out:
#            latitude     longitude      open  review_count         stars
# count  61184.000000  61184.000000     61184  61184.000000  61184.000000
# mean      37.326077    -97.491803  0.878089     28.272506      3.673305
# std        5.741085     29.624473  1.119995     88.652050      0.891207
# min       32.871923   -115.386550     False      3.000000      1.000000
# 25%       33.509601   -115.052224         1      4.000000      3.000000
# 50%       35.994636   -111.932944         1      8.000000      3.500000
# 75%       36.240430    -80.863329         1     21.000000      4.500000
# max       56.036545      8.549249      True   4578.000000      5.000000

# %%
data[data['city'].isin(['Karlsruhe'])]
# Out:
#                                               attributes  \
# 39022                                 {'Price Range': 3}
# 39023  {'Wheelchair Accessible': True, 'Accepts Credi...
# 39025                                 {'Price Range': 2}
# 39026                                 {'Price Range': 3}
# 39027  {'Wi-Fi': 'paid', 'Ambience': {'hipster': Fals...
# 39033                                 {'Price Range': 2}
# 39034  {'Price Range': 1, 'Accepts Credit Cards': Fal...
# 39040  {'Alcohol': 'beer_and_wine', 'Ambience': {'hip...
# 39041  {'Alcohol': 'beer_and_wine', 'Good For Kids': ...
# 39044  {'Alcohol': 'none', 'Good For': {'dessert': Fa...
# 39045  {'Alcohol': 'beer_and_wine', 'Good For Kids': ...
# 39046  {'Alcohol': 'beer_and_wine', 'Good For Groups'...
# 39047  {'Wi-Fi': 'no', 'Alcohol': 'beer_and_wine', 'G...
# 39048               {'Take-out': True, 'Price Range': 2}
# 39049  {'Wi-Fi': 'no', 'Alcohol': 'beer_and_wine', 'S...
# ...

# %%
data['city']
# Out:
# 0            Phoenix
# 1         Dravosburg
# 2        Bethel Park
# 3         Pittsburgh
# 4           Braddock
# 5           Carnegie
# 6           Carnegie
# 7           Carnegie
# 8           Carnegie
# 9           Carnegie
# 10          Carnegie
# 11          Carnegie
# 12          Carnegie
# 13          Carnegie
# 14          Carnegie
# 15          Carnegie
# 16          Carnegie
# 17          Carnegie
# 18          Carnegie
# 19          Carnegie
# 20          Carnegie
# 21        Pittsburgh
# 22          Carnegie
# 23          Carnegie
# 24        Pittsburgh
# 25         Homestead
# 26         Homestead
# 27         Homestead
# 28           Munhall
# 29           Munhall
#             ...
# 61154      Las Vegas
# 61155      Las Vegas
# 61156     Scottsdale
# 61157      Las Vegas
# 61158        Phoenix
# 61159        Phoenix
# 61160      Las Vegas
# 61161      Charlotte
# 61162    Sun Prairie
# 61163      Las Vegas
# 61164       Glendale
# 61165      Las Vegas
# ...

# %%
def plot_map(lons, lats, projection='mill', llcrnrlat=-80, urcrnrlat=90, llcrnrlon=-180, urcrnrlon=180, resolution='i', marker_size=2):
    m = Basemap(projection=projection, llcrnrlat=llcrnrlat, urcrnrlat=urcrnrlat, llcrnrlon=llcrnrlon, urcrnrlon=urcrnrlon, resolution=resolution)
    m.drawcoastlines()
    m.drawmapboundary()
    m.fillcontinents(color = '#333333')

    for lon, lat, msize in zip(lons, lats, marker_sizes):
        x, y = m(lon, lat)
        m.plot(x, y, '.r', markersize=msize, alpha=.7)

    return m

# %%
plot_map(data['longitude'], data['latitude'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-4e0a8b412def> in <module>()
# ----> 1 plot_map(data['longitude'], data['latitude'])
#
# <ipython-input-37-f041c33dab6d> in plot_map(lons, lats, projection, llcrnrlat, urcrnrlat, llcrnrlon, urcrnrlon, resolution, marker_size)
#       1 def plot_map(lons, lats, projection='mill', llcrnrlat=-80, urcrnrlat=90, llcrnrlon=-180, urcrnrlon=180, resolution='i', marker_size=2):
# ----> 2     m = Basemap(projection=projection, llcrnrlat=llcrnrlat, urcrnrlat=urcrnrlat, llcrnrlon=llcrnrlon, urcrnrlon=urcrnrlon, resolution=resolution)
#       3     m.drawcoastlines()
#       4     m.drawmapboundary()
#       5     m.fillcontinents(color = '#333333')
#
# NameError: name 'Basemap' is not defined
